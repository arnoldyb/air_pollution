# %%
import pandas as pd
import numpy as np 
import json
import datetime
import re
import ast

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Data Folder Instructions

# %%
# Use this cell to specify the paths for the data folder in your local machines
# Use the variable 'datafolder' to specify the path
# Comment out all the data paths except your own
# Purple Air data ia assumed to be in a subfolder called 'purpleair' 
# NOAA data ia assumed to be in a subfolder called 'noaa' 
# For example, if the base data folder is '/users/data', purpleair data should be in '/users/data/purpleair'

# Angshuman's local path
datafolder = "/Users/apaul2/Documents/_Common/capstone/Project/data"

# %% [markdown]
# ### Combine PurpleAir and NOAA data

# %%
purpleair_df = pd.read_csv("{}/purpleair/09141731_withaddress.csv".format(datafolder))
noaa_df = pd.read_parquet("{}/noaa/aug_asos_data_withloc.parquet".format(datafolder))

# %%
purpleair_df = purpleair_df.drop(['Unnamed: 0'], axis=1)
purpleair_df.head(2)
# Out:
#       age  a_h device_loc_typ  high_reading_flag  hidden  sensor_id  \
# 0  357358  NaN         inside                NaN   False      24115
# 1  357358  NaN            NaN                NaN   False      24116
#
#               sensor_name   last_seen        lat         lon  pm2_5val  \
# 0     2nd South 12th East  1547065985  40.764907 -111.856653      0.15
# 1   2nd South 12th East B  1547065988  40.764907 -111.856653       NaN
#
#    parent_id  thingspeak_primary_id thingspeak_primary_id_read_key  \
# 0        NaN                 672791               CLV9HLXOGIYQNYD2
# 1    24115.0                 672793               UQJBDQ2XXPP73U45
#
#    thingspeak_secondary_id thingspeak_secondary_id_read_key  \
# 0                   672792                 WAZLM3J4Q9OHKNGE
# 1                   672795                 5G9B9E4XFL32S845
#
#               sensor_type  humidity  is_owner  pressure  temp_f  \
# 0  PMS5003+PMS5003+BME280      15.0         0    869.14    89.0
# 1                     NaN      15.0         0    869.16    89.0
#
#    av_stat_last_modified  av_stat_time_since_last_modified  pm2_5val_10m_avg  \
# 0           1.547066e+12                           80079.0              0.47
# 1                    NaN                               NaN               NaN
#
#    pm2_5val_30m_avg  pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  \
# 0             19.37            34.37            16.29              4.76
# 1               NaN              NaN              NaN               NaN
#
#    pm2_5val_1wk_avg            city        country            county state  \
# 0              0.71  Salt Lake City  United States  Salt Lake County  Utah
# 1               NaN  Salt Lake City  United States  Salt Lake County  Utah
#
#   zipcode
# 0   84102
# 1   84102

# %%
noaa_df.head(2)
# Out:
#       wban_number call_sign call_sign2  year month day hour minute rec_length  \
# index
# 0           54779      K12N        12N  2019    08  01   00     00        099
# 1           54779      K12N        12N  2019    08  01   00     05        099
#
#            date timestamp interval call_sign3 zulu_time report_modifier  \
# index
# 0      08/01/19  00:00:31    5-MIN       K12N   010500Z            AUTO
# 1      08/01/19  00:05:31    5-MIN       K12N   010505Z            AUTO
#
#        wind_data wind_direction wind_speed  gusts gust_speed  variable_winds  \
# index
# 0           True            000          0  False                      False
# 1           True            000          0  False                      False
#
#       variable_wind_info  sys_maint_reqd  num_fields      lat       lon
# index
# 0                                  False          17  +41.009  -074.736
# 1                                  False          17  +41.009  -074.736

# %%
noaa_df.lat.nunique(), noaa_df.lon.nunique()
# Out:
# (933, 958)

# %%
purpleair_df.lat.nunique(), purpleair_df.lon.nunique()
# Out:
# (8507, 8506)

# %% [markdown]
# The next few cells are being used to test out the initial thoughts for combining the two dataframes.
# - Since we don't have the noaa data for September, the month data in noaa df will be replaced to mimic September.
# - The purple air data being used for this test was downloaded on 09/17 at 5:30 PM. Hence new columns with the corresponding timestamp will be added to the purple air df.
# - New columns will be added to both the dataframes to represent the integer portion of the lat and lon values as the weather station data is not available for all the lat and lon data in the purple air df. For this test, an exact match of these values will be used. However, we may need to use a range for the match.
# - Key columns will be created in both the dataframes by combining the date, time and lat-lon integer values and the same will be used to combine the datasets.

# %%
noaa_df_copy = noaa_df.copy()

# %%
noaa_df[['lat','lon']] = noaa_df[['lat','lon']].apply(pd.to_numeric)

# %%
# Add new lat-lon columns in with just the integer portions
# -- PURPLE AIR 
purpleair_df.loc[purpleair_df['lat'].notnull(), 'lat_int'] = purpleair_df.loc[purpleair_df['lat'].notnull(), 'lat'].apply(int)
purpleair_df.loc[purpleair_df['lon'].notnull(), 'lon_int'] = purpleair_df.loc[purpleair_df['lon'].notnull(), 'lon'].apply(int)
# -- NOAA DATA
noaa_df.loc[noaa_df['lat'].notnull(), 'lat_int'] = noaa_df.loc[noaa_df['lat'].notnull(), 'lat'].apply(int)
noaa_df.loc[noaa_df['lon'].notnull(), 'lon_int'] = noaa_df.loc[noaa_df['lon'].notnull(), 'lon'].apply(int)

# %%
# # Number of purple air records matching noaa records when considering just the integer portion of lat and lon
# purpleair_df[(purpleair_df.lat_int == 19) & (purpleair_df.lon_int == -155)].sensor_id.count()
# Out:
# 105

# %%
noaa_df[(noaa_df.timestamp == '17:30:31') & (noaa_df.date == '08/17/19')].wban_number.count()
# Out:
# 927

# %%
# Replace month values in noaa data - This should not be required once we have current data
noaa_df.month = '9'
noaa_df[['date']] = noaa_df[['date']].replace("08/", "09/", regex=True)

# %%
# Add date and time columns in purpleair df
purpleair_df['date'] = '09/17/19'
purpleair_df['timestamp'] = '17:30:31'

# %%
purpleair_df[['date','timestamp','lat_int','lon_int']].head()
# Out:
#        date timestamp  lat_int  lon_int
# 0  09/17/19  17:30:31     40.0   -111.0
# 1  09/17/19  17:30:31     40.0   -111.0
# 2  09/17/19  17:30:31     37.0   -121.0
# 3  09/17/19  17:30:31     37.0   -121.0
# 4  09/17/19  17:30:31     18.0    -67.0

# %%
noaa_df[['date','timestamp','lat_int','lon_int']].head()
# Out:
#            date timestamp  lat_int  lon_int
# index
# 0      09/01/19  00:00:31       41      -74
# 1      09/01/19  00:05:31       41      -74
# 2      09/01/19  00:10:31       41      -74
# 3      09/01/19  00:15:31       41      -74
# 4      09/01/19  00:20:31       41      -74

# %%
# import hashlib
# hashlib.sha256(b"test").hexdigest()

# %%
def createKey(row):
    if np.isnan(row['lat_int']):
        str_lat = ''
    else:
        str_lat = str(int(row['lat_int']))
        
        
    if np.isnan(row['lon_int']):
        str_lon = ''
    else:
        str_lon = str(int(row['lon_int']))
        
    return hash(str(row['date']) + str(row['timestamp']) + str_lat + str_lon)

# %%
# Create hashed key columns

# %%
ntest = noaa_df.copy()
ptest = purpleair_df.copy()

# %%
noaa_df['df_key'] = noaa_df.apply (lambda row: createKey(row), axis=1)

# %%
purpleair_df['df_key'] = purpleair_df.apply (lambda row: createKey(row), axis=1)

# %%
merged_df = pd.merge(purpleair_df, noaa_df, on='df_key')

# %%
merged_df.head()
# Out:
#       age  a_h device_loc_typ  high_reading_flag  hidden  sensor_id  \
# 0  357358  NaN         inside                NaN   False      24115
# 1  357358  NaN            NaN                NaN   False      24116
# 2       0  NaN        outside                NaN   False      10808
# 3       0  NaN            NaN                NaN   False      10809
# 4       1  NaN        outside                1.0   False       5460
#
#               sensor_name   last_seen      lat_x       lon_x  pm2_5val  \
# 0     2nd South 12th East  1547065985  40.764907 -111.856653      0.15
# 1   2nd South 12th East B  1547065988  40.764907 -111.856653       NaN
# 2          1-800 Contacts  1568507501  40.507316 -111.899188      2.46
# 3        1-800 Contacts B  1568507501  40.507316 -111.899188      2.19
# 4          1027 Hollywood  1568507441  40.727510 -111.861434      3.44
#
#    parent_id  thingspeak_primary_id thingspeak_primary_id_read_key  \
# 0        NaN                 672791               CLV9HLXOGIYQNYD2
# 1    24115.0                 672793               UQJBDQ2XXPP73U45
# 2        NaN                 496465               NJQEPVB0BHDCQKXA
# 3    10808.0                 496467               U9BJQDBKB38741GM
# 4        NaN                 385885               5CPPE62979927J8N
#
#    thingspeak_secondary_id thingspeak_secondary_id_read_key  \
# 0                   672792                 WAZLM3J4Q9OHKNGE
# 1                   672795                 5G9B9E4XFL32S845
# 2                   496466                 68WPXUEO026F8BB9
# 3                   496468                 SICXKXJEM9WTQZ5O
# 4                   385886                 CY94WZ0PXRIG4FP9
#
#               sensor_type  humidity  is_owner  pressure  temp_f  \
# 0  PMS5003+PMS5003+BME280      15.0         0    869.14    89.0
# 1                     NaN      15.0         0    869.16    89.0
# 2  PMS5003+PMS5003+BME280       5.0         0    866.64    98.0
# 3                     NaN       NaN         0       NaN     NaN
# 4  PMS5003+PMS5003+BME280      10.0         0    869.12    97.0
#
#    av_stat_last_modified  av_stat_time_since_last_modified  pm2_5val_10m_avg  \
# 0           1.547066e+12                           80079.0              0.47
# 1                    NaN                               NaN               NaN
# 2           1.568508e+12                          120174.0              2.55
# 3           1.568508e+12                          120174.0              2.52
# 4           1.568507e+12                          119929.0              2.94
#
#    pm2_5val_30m_avg  pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  \
# 0             19.37            34.37            16.29              4.76
# 1               NaN              NaN              NaN               NaN
# 2              2.64             2.75             5.20              8.08
# 3              2.67             2.82             5.53              8.55
# 4              2.74             2.88             4.31              6.71
#
#    pm2_5val_1wk_avg            city        country            county state  \
# 0              0.71  Salt Lake City  United States  Salt Lake County  Utah
# 1               NaN  Salt Lake City  United States  Salt Lake County  Utah
# 2              7.07          Draper  United States               NaN  Utah
# 3              7.46          Draper  United States               NaN  Utah
# 4              6.28  Salt Lake City  United States  Salt Lake County  Utah
#
#   zipcode  lat_int_x  lon_int_x    date_x timestamp_x               df_key  \
# 0   84102       40.0     -111.0  09/17/19    17:30:31  4483277121292122113
# 1   84102       40.0     -111.0  09/17/19    17:30:31  4483277121292122113
# 2   84020       40.0     -111.0  09/17/19    17:30:31  4483277121292122113
# 3   84020       40.0     -111.0  09/17/19    17:30:31  4483277121292122113
# 4   84105       40.0     -111.0  09/17/19    17:30:31  4483277121292122113
#
#   wban_number call_sign call_sign2  year month day hour minute rec_length  \
# 0       24127      KSLC        SLC  2019     9  17   17     30        106
# 1       24127      KSLC        SLC  2019     9  17   17     30        106
# 2       24127      KSLC        SLC  2019     9  17   17     30        106
# 3       24127      KSLC        SLC  2019     9  17   17     30        106
# 4       24127      KSLC        SLC  2019     9  17   17     30        106
#
#      date_y timestamp_y interval call_sign3 zulu_time report_modifier  \
# 0  09/17/19    17:30:31    5-MIN       KSLC   180030Z
# 1  09/17/19    17:30:31    5-MIN       KSLC   180030Z
# 2  09/17/19    17:30:31    5-MIN       KSLC   180030Z
# 3  09/17/19    17:30:31    5-MIN       KSLC   180030Z
# 4  09/17/19    17:30:31    5-MIN       KSLC   180030Z
#
#    wind_data wind_direction wind_speed  gusts gust_speed  variable_winds  \
# 0       True            350          9  False                      False
# 1       True            350          9  False                      False
# 2       True            350          9  False                      False
# 3       True            350          9  False                      False
# 4       True            350          9  False                      False
#
#   variable_wind_info  sys_maint_reqd  num_fields   lat_y    lon_y  lat_int_y  \
# 0                               True          19  40.778 -111.969         40
# 1                               True          19  40.778 -111.969         40
# 2                               True          19  40.778 -111.969         40
# 3                               True          19  40.778 -111.969         40
# 4                               True          19  40.778 -111.969         40
#
#    lon_int_y
# 0       -111
# 1       -111
# 2       -111
# 3       -111
# 4       -111

# %% [markdown]
# Some of the records are getting multiple matches with the current logic. May have to include some decimal precision to find more accurate matches

# %%
purpleair_df[purpleair_df.sensor_id == 18279]
# Out:
#        age  a_h device_loc_typ  high_reading_flag  hidden  sensor_id  \
# 16914    0  NaN        outside                NaN   False      18279
#
#                                              sensor_name   last_seen  \
# 16914  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
#
#              lat        lon  pm2_5val  parent_id  thingspeak_primary_id  \
# 16914  42.367905 -71.091116      3.73        NaN                 616598
#
#       thingspeak_primary_id_read_key  thingspeak_secondary_id  \
# 16914               NRI5KG0D337Q9YPI                   616599
#
#       thingspeak_secondary_id_read_key             sensor_type  humidity  \
# 16914                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
#
#        is_owner  pressure  temp_f  av_stat_last_modified  \
# 16914         0   1021.19    77.0           1.568507e+12
#
#        av_stat_time_since_last_modified  pm2_5val_10m_avg  pm2_5val_30m_avg  \
# 16914                          119886.0              4.85              5.13
#
#        pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  pm2_5val_1wk_avg  \
# 16914             4.63             2.72              3.93              5.58
#
#             city        country            county          state zipcode  \
# 16914  Cambridge  United States  Middlesex County  Massachusetts   02141
#
#        lat_int  lon_int      date timestamp               df_key
# 16914     42.0    -71.0  09/17/19  17:30:31 -4432959759473775883

# %%
merged_df[merged_df.sensor_id == 18279]
# Out:
#        age  a_h device_loc_typ  high_reading_flag  hidden  sensor_id  \
# 37967    0  NaN        outside                NaN   False      18279
# 37968    0  NaN        outside                NaN   False      18279
# 37969    0  NaN        outside                NaN   False      18279
# 37970    0  NaN        outside                NaN   False      18279
# 37971    0  NaN        outside                NaN   False      18279
# 37972    0  NaN        outside                NaN   False      18279
# 37973    0  NaN        outside                NaN   False      18279
# 37974    0  NaN        outside                NaN   False      18279
#
#                                              sensor_name   last_seen  \
# 37967  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37968  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37969  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37970  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37971  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37972  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37973  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
# 37974  Wellington-Harrington, Cardinal Medeiros, One ...  1568507482
#
#            lat_x      lon_x  pm2_5val  parent_id  thingspeak_primary_id  \
# 37967  42.367905 -71.091116      3.73        NaN                 616598
# 37968  42.367905 -71.091116      3.73        NaN                 616598
# 37969  42.367905 -71.091116      3.73        NaN                 616598
# 37970  42.367905 -71.091116      3.73        NaN                 616598
# 37971  42.367905 -71.091116      3.73        NaN                 616598
# 37972  42.367905 -71.091116      3.73        NaN                 616598
# 37973  42.367905 -71.091116      3.73        NaN                 616598
# 37974  42.367905 -71.091116      3.73        NaN                 616598
#
#       thingspeak_primary_id_read_key  thingspeak_secondary_id  \
# 37967               NRI5KG0D337Q9YPI                   616599
# 37968               NRI5KG0D337Q9YPI                   616599
# 37969               NRI5KG0D337Q9YPI                   616599
# 37970               NRI5KG0D337Q9YPI                   616599
# 37971               NRI5KG0D337Q9YPI                   616599
# 37972               NRI5KG0D337Q9YPI                   616599
# 37973               NRI5KG0D337Q9YPI                   616599
# 37974               NRI5KG0D337Q9YPI                   616599
#
#       thingspeak_secondary_id_read_key             sensor_type  humidity  \
# 37967                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37968                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37969                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37970                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37971                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37972                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37973                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
# 37974                 2HQS4UWA3M3YQG8W  PMS5003+PMS5003+BME280      61.0
#
#        is_owner  pressure  temp_f  av_stat_last_modified  \
# 37967         0   1021.19    77.0           1.568507e+12
# 37968         0   1021.19    77.0           1.568507e+12
# 37969         0   1021.19    77.0           1.568507e+12
# 37970         0   1021.19    77.0           1.568507e+12
# 37971         0   1021.19    77.0           1.568507e+12
# 37972         0   1021.19    77.0           1.568507e+12
# 37973         0   1021.19    77.0           1.568507e+12
# 37974         0   1021.19    77.0           1.568507e+12
#
#        av_stat_time_since_last_modified  pm2_5val_10m_avg  pm2_5val_30m_avg  \
# 37967                          119886.0              4.85              5.13
# 37968                          119886.0              4.85              5.13
# 37969                          119886.0              4.85              5.13
# 37970                          119886.0              4.85              5.13
# 37971                          119886.0              4.85              5.13
# 37972                          119886.0              4.85              5.13
# 37973                          119886.0              4.85              5.13
# 37974                          119886.0              4.85              5.13
#
#        pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  pm2_5val_1wk_avg  \
# 37967             4.63             2.72              3.93              5.58
# 37968             4.63             2.72              3.93              5.58
# 37969             4.63             2.72              3.93              5.58
# 37970             4.63             2.72              3.93              5.58
# 37971             4.63             2.72              3.93              5.58
# 37972             4.63             2.72              3.93              5.58
# 37973             4.63             2.72              3.93              5.58
# 37974             4.63             2.72              3.93              5.58
#
#             city        country            county          state zipcode  \
# 37967  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37968  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37969  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37970  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37971  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37972  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37973  Cambridge  United States  Middlesex County  Massachusetts   02141
# 37974  Cambridge  United States  Middlesex County  Massachusetts   02141
#
#        lat_int_x  lon_int_x    date_x timestamp_x               df_key  \
# 37967       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37968       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37969       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37970       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37971       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37972       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37973       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
# 37974       42.0      -71.0  09/17/19    17:30:31 -4432959759473775883
#
#       wban_number call_sign call_sign2  year month day hour minute rec_length  \
# 37967       14702      KBED        BED  2019     9  17   17     30        104
# 37968       14739      KBOS        BOS  2019     9  17   17     30        112
# 37969       04780      KFIT        FIT  2019     9  17   17     30        111
# 37970       14710      KMHT        MHT  2019     9  17   17     30        120
# 37971       14710      KMHT        MHT  2019     9  17   17     30        120
# 37972       14753      KMQE        MQE  2019     9  17   17     30        099
# 37973       94746      KORH        ORH  2019     9  17   17     30        113
# 37974       54704      KOWD        OWD  2019     9  17   17     30        121
#
#          date_y timestamp_y interval call_sign3 zulu_time report_modifier  \
# 37967  09/17/19    17:30:31    5-MIN       KBED   172230Z
# 37968  09/17/19    17:30:31    5-MIN       KBOS   172230Z
# 37969  09/17/19    17:30:31    5-MIN       KFIT   172230Z            AUTO
# 37970  09/17/19    17:30:31    5-MIN       KMHT   172230Z
# 37971  09/17/19    17:30:31    5-MIN       KMHT   172230Z
# 37972  09/17/19    17:30:31    5-MIN       KMQE   172230Z            AUTO
# 37973  09/17/19    17:30:31    5-MIN       KORH   172230Z
# 37974  09/17/19    17:30:31    5-MIN       KOWD   172230Z
#
#        wind_data wind_direction wind_speed  gusts gust_speed  variable_winds  \
# 37967       True            100          7  False                      False
# 37968       True            100         11  False                      False
# 37969       True            150          6  False                      False
# 37970       True            120          6  False                      False
# 37971       True            120          6  False                      False
# 37972       True            140          7  False                      False
# 37973       True            150          9  False                      False
# 37974       True            140          4  False                      False
#
#       variable_wind_info  sys_maint_reqd  num_fields   lat_y   lon_y  \
# 37967                               True          19  42.470 -71.289
# 37968                              False          19  42.361 -71.010
# 37969                              False          19  42.552 -71.756
# 37970                              False          20  42.930 -71.436
# 37971                              False          20  42.933 -71.438
# 37972                              False          17  42.212 -71.114
# 37973                              False          19  42.271 -71.873
# 37974                               True          21  42.191 -71.174
#
#        lat_int_y  lon_int_y
# 37967         42        -71
# 37968         42        -71
# 37969         42        -71
# 37970         42        -71
# 37971         42        -71
# 37972         42        -71
# 37973         42        -71
# 37974         42        -71

# %%
# Number of countries for which we have wind and sensor data
merged_df.country.unique()
# Out:
# array(['United States', 'Mexico', 'Canada', 'Guam', 'U.S. Virgin Islands',
#        'British Virgin Islands'], dtype=object)

# %% [markdown]
# Purple Air data had records for 105 countries while combining wind data restricts it to 6

# %%
# Purple Air state counts
pa_usa_st_ct = purpleair_df[purpleair_df.country == 'United States'].state.nunique()
pa_mex_st_ct = purpleair_df[purpleair_df.country == 'Mexico'].state.nunique()
pa_can_st_ct = purpleair_df[purpleair_df.country == 'Canada'].state.nunique()
# Merged data state counts
merged_usa_st_ct = merged_df[merged_df.country == 'United States'].state.nunique()
merged_mex_st_ct = merged_df[merged_df.country == 'Mexico'].state.nunique()
merged_can_st_ct = merged_df[merged_df.country == 'Canada'].state.nunique()

print("Purple Air data had records for {} states in USA and combined wind data has {}".format(pa_usa_st_ct, merged_usa_st_ct))
print("Purple Air data had records for {} states in Mexico and combined wind data has {}".format(pa_mex_st_ct, merged_mex_st_ct))
print("Purple Air data had records for {} states in Canada and combined wind data has {}".format(pa_can_st_ct, merged_can_st_ct))
# Out:
# Purple Air data had records for 51 states in USA while combining wind data has 51
# Purple Air data had records for 11 states in Mexico while combining wind data has 1
# Purple Air data had records for 7 states in Canada while combining wind data has 2
