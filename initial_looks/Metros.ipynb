# %% [markdown]
# # Where are the most sensors by region?
# The US government has a number of ways to classify regions. One is the Metropolitan Statistical Area (MSA). This looks to be about the right unit of measurement, as it works mostly with urban/suburban areas rather than drawing in huge exurban spaces.

# %%
import pandas as pd
import pandas_profiling
import numpy as np 
import json
import datetime
import re
import ast

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 500)

# %%
# Use this cell to specify the paths for the data folder in your local machines
# Use the variable 'datafolder' to specify the path
# Comment out all the data paths except your own
# Purple Air data ia assumed to be in a subfolder called 'purpleair' 
# For example, if the base data folder is '/users/data', purpleair data should be in '/users/data/purpleair'

# Ben's local path
datafolder = "../my_stash/data"

# %%
purpleair_df = pd.read_csv("{}/purpleair/09141731_withaddress.csv".format(datafolder))
zipmsa_df = pd.read_csv("{}/zip_msa.csv".format(datafolder)) # purchased from:
# zipinfo.com/products/z5msa/z5msa.htm
regions_df = pd.read_csv("{}/msapmsa.csv".format(datafolder)) # purchased from same

# %%
zipmsa_df.rename(columns = {'ZIP':'zipcode'}, inplace = True) # standardize the column name

# %%
# handle NaNs in the PurpleAir zipcode field
replace_col = []
for i in purpleair_df['zipcode']:
    try:
        i = int(i)
    except:
        i = 0
    replace_col.append(i)
purpleair_df['zipcode'] = replace_col

# %%
purpleair_df.astype({'zipcode': 'int64'}) # set them to integer type
# Out:
#        Unnamed: 0     age  a_h device_loc_typ  high_reading_flag  hidden  \
# 0               0  357358  NaN         inside                NaN   False
# 1               1  357358  NaN            NaN                NaN   False
# 2               2   99019  NaN        outside                NaN   False
# 3               3   99019  NaN            NaN                NaN   False
# 4               4       0  NaN        outside                NaN   False
# ...           ...     ...  ...            ...                ...     ...
# 17539       17539  381884  NaN            NaN                NaN   False
# 17540       17540       1  NaN        outside                1.0   False
# 17541       17541       1  NaN            NaN                1.0   False
# 17542       17542       0  NaN        outside                NaN   False
# 17543       17543       0  NaN            NaN                NaN   False
#
#        sensor_id                sensor_name   last_seen        lat  \
# 0          24115        2nd South 12th East  1547065985  40.764907
# 1          24116      2nd South 12th East B  1547065988  40.764907
# 2          27699                       CHA1  1562566345  37.929030
# 3          27700                     CHA1 B  1562566345  37.929030
# 4          16791                     DW0435  1568507486  18.082454
# ...          ...                        ...         ...        ...
# 17539      22218          Zuffi Domicilio B  1545594436  37.303701
# 17540      15207    __SilvanaTerraceSensor1  1568507432  48.203071
# 17541      15208  __SilvanaTerraceSensor1 B  1568507432  48.203071
# 17542      15211    __SilvanaTerraceSensor2  1568507469  48.203800
# 17543      15212  __SilvanaTerraceSensor2 B  1568507469  48.203800
#
#               lon  pm2_5val  parent_id  thingspeak_primary_id  \
# 0     -111.856653      0.15        NaN                 672791
# 1     -111.856653       NaN    24115.0                 672793
# 2     -121.940127      3.13        NaN                 716094
# 3     -121.940127      3.22    27699.0                 716096
# 4      -67.039027      1.47        NaN                 589048
# ...           ...       ...        ...                    ...
# 17539 -121.773327       NaN    22217.0                 652930
# 17540 -122.289081      3.16        NaN                 573192
# 17541 -122.289081      3.06    15207.0                 573195
# 17542 -122.288882      2.09        NaN                 573199
# 17543 -122.288882      2.50    15211.0                 573202
#
#       thingspeak_primary_id_read_key  thingspeak_secondary_id  \
# 0                   CLV9HLXOGIYQNYD2                   672792
# 1                   UQJBDQ2XXPP73U45                   672795
# 2                   M57A4C3IH3QFM9N6                   716095
# 3                   9CI7CR8RAJJ4UZC7                   716097
# 4                   61GKVZGTCZSBUGB5                   589049
# ...                              ...                      ...
# 17539               YF5HTYQKFTLLWWSE                   652931
# 17540               2JVEOVLU389JBIKL                   573194
# 17541               0538JMKEJZY8I4K0                   573196
# 17542               NBCUX44B85C1D1LH                   573201
# 17543               5TVYTMRH0UVWCLCH                   573203
#
#       thingspeak_secondary_id_read_key             sensor_type  humidity  \
# 0                     WAZLM3J4Q9OHKNGE  PMS5003+PMS5003+BME280      15.0
# 1                     5G9B9E4XFL32S845                     NaN      15.0
# 2                     7U439FCFH7XFYY2V  PMS5003+PMS5003+BME280      26.0
# 3                     6CE24ETYNU310ABD                     NaN       NaN
# 4                     5HBLH5R8GPLM6J88  PMS5003+PMS5003+BME280      58.0
# ...                                ...                     ...       ...
# 17539                 H05KWOGIXM4CR999                     NaN      36.0
# 17540                 5K8M358MOAFRRBRG  PMS5003+PMS5003+BME280      51.0
# 17541                 6VJ9ZQQJE2GU6KL6                     NaN       NaN
# 17542                 GP83RBKIOKCJJAPP  PMS5003+PMS5003+BME280      58.0
# 17543                 U8V5IUIVJS5LRM46                     NaN       NaN
#
#        is_owner  pressure  temp_f  av_stat_last_modified  \
# 0             0    869.14    89.0           1.547066e+12
# 1             0    869.16    89.0                    NaN
# 2             0    995.19    74.0           1.562566e+12
# 3             0       NaN     NaN           1.562566e+12
# 4             0   1009.83    96.0           1.568507e+12
# ...         ...       ...     ...                    ...
# 17539         0   1014.88    73.0                    NaN
# 17540         0   1011.76    76.0           1.568507e+12
# 17541         0       NaN     NaN           1.568507e+12
# 17542         0   1011.20    74.0           1.568507e+12
# 17543         0       NaN     NaN           1.568507e+12
#
#        av_stat_time_since_last_modified  pm2_5val_10m_avg  pm2_5val_30m_avg  \
# 0                               80079.0              0.47             19.37
# 1                                   NaN               NaN               NaN
# 2                              119968.0              3.38              3.43
# 3                              119969.0              3.44              3.52
# 4                              119763.0              1.78              1.53
# ...                                 ...               ...               ...
# 17539                               NaN               NaN               NaN
# 17540                          120175.0              2.92              2.87
# 17541                          120175.0              3.26              3.15
# 17542                          120024.0              3.08              3.04
# 17543                          120024.0              2.88              2.84
#
#        pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  pm2_5val_1wk_avg  \
# 0                34.37            16.29              4.76              0.71
# 1                  NaN              NaN               NaN               NaN
# 2                 3.93             6.40              6.79              4.48
# 3                 4.08             6.69              7.13              4.76
# 4                 1.51             2.29              2.97              3.95
# ...                ...              ...               ...               ...
# 17539              NaN              NaN               NaN               NaN
# 17540             2.67             2.55              3.13              5.19
# 17541             2.93             2.88              3.50              5.70
# 17542             2.83             3.03              3.56              5.52
# 17543             2.62             2.76              3.25              4.98
#
#                  city        country               county       state  zipcode
# 0      Salt Lake City  United States     Salt Lake County        Utah    84102
# 1      Salt Lake City  United States     Salt Lake County        Utah    84102
# 2             Clayton  United States  Contra Costa County  California    94517
# 3             Clayton  United States  Contra Costa County  California    94517
# 4          San Germán    Puerto Rico           San Germán         NaN      683
# ...               ...            ...                  ...         ...      ...
# 17539        San Jose  United States   Santa Clara County  California    95135
# 17540        Stanwood  United States     Snohomish County  Washington    98292
# 17541        Stanwood  United States     Snohomish County  Washington    98292
# 17542        Stanwood  United States     Snohomish County  Washington    98292
# 17543        Stanwood  United States     Snohomish County  Washington    98292
#
# [17544 rows x 35 columns]

# %%
# merge the purple air data with the metro data
merged_df = pd.merge(purpleair_df, zipmsa_df, on='zipcode')

# %%
merged_df.head()
# Out:
#    Unnamed: 0     age  a_h device_loc_typ  high_reading_flag  hidden  \
# 0           0  357358  NaN         inside                NaN   False
# 1           1  357358  NaN            NaN                NaN   False
# 2         122  390462  NaN         inside                NaN   False
# 3         123  390462  NaN            NaN                NaN   False
# 4         592   25726  NaN         inside                NaN   False
#
#    sensor_id             sensor_name   last_seen        lat         lon  \
# 0      24115     2nd South 12th East  1547065985  40.764907 -111.856653
# 1      24116   2nd South 12th East B  1547065988  40.764907 -111.856653
# 2      22845      115s 1100e slc;ut.  1545079733  40.766638 -111.859077
# 3      22846    115s 1100e slc;ut. B  1545079763  40.766638 -111.859077
# 4      23505                 8th&8th  1566963933  40.751973 -111.868187
#
#    pm2_5val  parent_id  thingspeak_primary_id thingspeak_primary_id_read_key  \
# 0      0.15        NaN                 672791               CLV9HLXOGIYQNYD2
# 1       NaN    24115.0                 672793               UQJBDQ2XXPP73U45
# 2      0.06        NaN                 656576               OBFA3BXTIOMTQFT9
# 3       NaN    22845.0                 656578               26J28OUCV6WFFHVU
# 4      4.36        NaN                 660357               7KO16799H7RHQFI8
#
#    thingspeak_secondary_id thingspeak_secondary_id_read_key  \
# 0                   672792                 WAZLM3J4Q9OHKNGE
# 1                   672795                 5G9B9E4XFL32S845
# 2                   656577                 V7R2K8M07V7RDZ59
# 3                   656579                 NYDECD3UY4TF4U62
# 4                   660358                 4NH5ZIFKCCFPKUSH
#
#               sensor_type  humidity  is_owner  pressure  temp_f  \
# 0  PMS5003+PMS5003+BME280      15.0         0    869.14    89.0
# 1                     NaN      15.0         0    869.16    89.0
# 2  PMS5003+PMS5003+BME280      18.0         0    867.77    77.0
# 3                     NaN      18.0         0    867.76    77.0
# 4  PMS5003+PMS5003+BME280      20.0         0    871.56    93.0
#
#    av_stat_last_modified  av_stat_time_since_last_modified  pm2_5val_10m_avg  \
# 0           1.547066e+12                           80079.0              0.47
# 1                    NaN                               NaN               NaN
# 2           1.545080e+12                           79299.0             20.38
# 3                    NaN                               NaN               NaN
# 4           1.566964e+12                          119983.0              3.90
#
#    pm2_5val_30m_avg  pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  \
# 0             19.37            34.37            16.29              4.76
# 1               NaN              NaN              NaN               NaN
# 2             30.45            21.90             4.92              1.29
# 3               NaN              NaN              NaN               NaN
# 4              4.15             3.89             3.41              3.62
#
#    pm2_5val_1wk_avg            city        country            county state  \
# 0              0.71  Salt Lake City  United States  Salt Lake County  Utah
# 1               NaN  Salt Lake City  United States  Salt Lake County  Utah
# 2              0.19  Salt Lake City  United States  Salt Lake County  Utah
# 3               NaN  Salt Lake City  United States  Salt Lake County  Utah
# 4              3.64  Salt Lake City  United States  Salt Lake County  Utah
#
#    zipcode            City  ST    A/C     FIPS     County  T/Z DST?     MSA  \
# 0    84102  Salt Lake City  UT  801.0  49035.0  Salt Lake  MST    Y  7160.0
# 1    84102  Salt Lake City  UT  801.0  49035.0  Salt Lake  MST    Y  7160.0
# 2    84102  Salt Lake City  UT  801.0  49035.0  Salt Lake  MST    Y  7160.0
# 3    84102  Salt Lake City  UT  801.0  49035.0  Salt Lake  MST    Y  7160.0
# 4    84102  Salt Lake City  UT  801.0  49035.0  Salt Lake  MST    Y  7160.0
#
#    PMSA Type
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN

# %%
# handle NaNs in the metro data
replace_col = []
for row in range(len(merged_df)):
    i = merged_df.loc[row].MSA
    j = merged_df.loc[row].PMSA
    try:
        i = int(i)
    except:
        try:
            i = int(j)
        except:
            i = 0
    replace_col.append(i)
merged_df['metrocode'] = replace_col

# %%
merged_df
# Out:
#        Unnamed: 0     age  a_h device_loc_typ  high_reading_flag  hidden  \
# 0               0  357358  NaN         inside                NaN   False
# 1               1  357358  NaN            NaN                NaN   False
# 2             122  390462  NaN         inside                NaN   False
# 3             123  390462  NaN            NaN                NaN   False
# 4             592   25726  NaN         inside                NaN   False
# ...           ...     ...  ...            ...                ...     ...
# 14422       17521  178057  NaN            NaN                NaN   False
# 14423       17524  321180  NaN        outside                NaN   False
# 14424       17525  321180  NaN            NaN                NaN   False
# 14425       17536       0  NaN        outside                NaN   False
# 14426       17537       0  NaN            NaN                NaN   False
#
#        sensor_id             sensor_name   last_seen        lat         lon  \
# 0          24115     2nd South 12th East  1547065985  40.764907 -111.856653
# 1          24116   2nd South 12th East B  1547065988  40.764907 -111.856653
# 2          22845      115s 1100e slc;ut.  1545079733  40.766638 -111.859077
# 3          22846    115s 1100e slc;ut. B  1545079763  40.766638 -111.859077
# 4          23505                 8th&8th  1566963933  40.751973 -111.868187
# ...          ...                     ...         ...        ...         ...
# 14422      12247         Zeughaushof 2 B  1557824059  47.377600    8.530420
# 14423      11660                Zillmere  1549236669 -27.364016  153.033164
# 14424      11661              Zillmere B  1549236673 -27.364016  153.033164
# 14425      22607              zombieland  1568507459  36.158086 -115.362767
# 14426      22608            zombieland B  1568507459  36.158086 -115.362767
#
#        pm2_5val  parent_id  thingspeak_primary_id  \
# 0          0.15        NaN                 672791
# 1           NaN    24115.0                 672793
# 2          0.06        NaN                 656576
# 3           NaN    22845.0                 656578
# 4          4.36        NaN                 660357
# ...         ...        ...                    ...
# 14422      8.50    12246.0                 527112
# 14423      1.28        NaN                 511805
# 14424      1.87    11660.0                 511807
# 14425      4.28        NaN                 654347
# 14426      3.38    22607.0                 654349
#
#       thingspeak_primary_id_read_key  thingspeak_secondary_id  \
# 0                   CLV9HLXOGIYQNYD2                   672792
# 1                   UQJBDQ2XXPP73U45                   672795
# 2                   OBFA3BXTIOMTQFT9                   656577
# 3                   26J28OUCV6WFFHVU                   656579
# 4                   7KO16799H7RHQFI8                   660358
# ...                              ...                      ...
# 14422               6850DM8F8XT5DCW1                   527113
# 14423               33QYYA4PHRX0MB7Y                   511806
# 14424               7JDC0KWXY8NAZSD3                   511808
# 14425               O7NK1R67KFEOL0K9                   654348
# 14426               5PZR8CBGBRCZF1Z4                   654350
#
#       thingspeak_secondary_id_read_key             sensor_type  humidity  \
# 0                     WAZLM3J4Q9OHKNGE  PMS5003+PMS5003+BME280      15.0
# 1                     5G9B9E4XFL32S845                     NaN      15.0
# 2                     V7R2K8M07V7RDZ59  PMS5003+PMS5003+BME280      18.0
# 3                     NYDECD3UY4TF4U62                     NaN      18.0
# 4                     4NH5ZIFKCCFPKUSH  PMS5003+PMS5003+BME280      20.0
# ...                                ...                     ...       ...
# 14422                 EXINYPXBQGJ7V8P0                     NaN      22.0
# 14423                 EU23TN1RRSTF9WXH  PMS5003+PMS5003+BME280      57.0
# 14424                 T1BEQOBSIIZH8UCH                     NaN      57.0
# 14425                 6T8TV55XJ5QUDATV  PMS5003+PMS5003+BME280       5.0
# 14426                 JC0VKN0D56BQZ2MX                     NaN       NaN
#
#        is_owner  pressure  temp_f  av_stat_last_modified  \
# 0             0    869.14    89.0           1.547066e+12
# 1             0    869.16    89.0                    NaN
# 2             0    867.77    77.0           1.545080e+12
# 3             0    867.76    77.0                    NaN
# 4             0    871.56    93.0           1.566964e+12
# ...         ...       ...     ...                    ...
# 14422         0    979.26    68.0           1.557824e+12
# 14423         0   1011.03    86.0           1.549237e+12
# 14424         0   1011.02    86.0           1.549237e+12
# 14425         0    902.16   107.0           1.568507e+12
# 14426         0       NaN     NaN           1.568507e+12
#
#        av_stat_time_since_last_modified  pm2_5val_10m_avg  pm2_5val_30m_avg  \
# 0                               80079.0              0.47             19.37
# 1                                   NaN               NaN               NaN
# 2                               79299.0             20.38             30.45
# 3                                   NaN               NaN               NaN
# 4                              119983.0              3.90              4.15
# ...                                 ...               ...               ...
# 14422                           77115.0             10.85             11.63
# 14423                           80018.0              1.93              2.48
# 14424                           79850.0              2.14              2.70
# 14425                          119986.0              3.93              3.88
# 14426                          119987.0              3.04              3.17
#
#        pm2_5val_1h_avg  pm2_5val_6h_avg  pm2_5val_24h_avg  pm2_5val_1wk_avg  \
# 0                34.37            16.29              4.76              0.71
# 1                  NaN              NaN               NaN               NaN
# 2                21.90             4.92              1.29              0.19
# 3                  NaN              NaN               NaN               NaN
# 4                 3.89             3.41              3.62              3.64
# ...                ...              ...               ...               ...
# 14422            10.49             7.88              7.61             10.45
# 14423             3.26             3.24              2.28              2.46
# 14424             3.47             3.46              2.45              2.52
# 14425             3.87             3.99              4.33              3.36
# 14426             3.21             3.24              3.46              2.51
#
#                  city        country            county       state  zipcode  \
# 0      Salt Lake City  United States  Salt Lake County        Utah    84102
# 1      Salt Lake City  United States  Salt Lake County        Utah    84102
# 2      Salt Lake City  United States  Salt Lake County        Utah    84102
# 3      Salt Lake City  United States  Salt Lake County        Utah    84102
# 4      Salt Lake City  United States  Salt Lake County        Utah    84102
# ...               ...            ...               ...         ...      ...
# 14422          Zürich    Switzerland            Zürich      Zürich     8004
# 14423        Zillmere      Australia     Brisbane City  Queensland     4034
# 14424        Zillmere      Australia     Brisbane City  Queensland     4034
# 14425       Las Vegas  United States      Clark County      Nevada    89138
# 14426       Las Vegas  United States      Clark County      Nevada    89138
#
#                  City  ST    A/C     FIPS      County  T/Z DST?     MSA  \
# 0      Salt Lake City  UT  801.0  49035.0   Salt Lake  MST    Y  7160.0
# 1      Salt Lake City  UT  801.0  49035.0   Salt Lake  MST    Y  7160.0
# 2      Salt Lake City  UT  801.0  49035.0   Salt Lake  MST    Y  7160.0
# 3      Salt Lake City  UT  801.0  49035.0   Salt Lake  MST    Y  7160.0
# 4      Salt Lake City  UT  801.0  49035.0   Salt Lake  MST    Y  7160.0
# ...               ...  ..    ...      ...         ...  ...  ...     ...
# 14422            Atco  NJ  856.0  34007.0      Camden  EST    Y     NaN
# 14423        Freeport  ME  207.0  23005.0  Cumberland  EST    Y  6400.0
# 14424        Freeport  ME  207.0  23005.0  Cumberland  EST    Y  6400.0
# 14425       Las Vegas  NV  702.0  32003.0       Clark  PST    Y  4120.0
# 14426       Las Vegas  NV  702.0  32003.0       Clark  PST    Y  4120.0
#
#          PMSA Type  metrocode
# 0         NaN  NaN       7160
# 1         NaN  NaN       7160
# 2         NaN  NaN       7160
# 3         NaN  NaN       7160
# 4         NaN  NaN       7160
# ...       ...  ...        ...
# 14422  6160.0  NaN       6160
# 14423     NaN    U       6400
# 14424     NaN    U       6400
# 14425     NaN  NaN       4120
# 14426     NaN  NaN       4120
#
# [14427 rows x 46 columns]

# %%
# count the sensors in each metro region
MSA_counts = merged_df['metrocode'].value_counts()

# %%
# remove NaNs from the regional name lookup data
replace_col = []
for i in range(len(regions_df)):
    try:
        i = int(regions_df.loc[i]['Metro Area'])
    except:
        i = -1
    replace_col.append(i)
regions_df['Metro Area'] = replace_col

# %%
# output sorted list of all metro regions with the sensor numbers, in descending order

metro_name = ''
for MSA in MSA_counts.keys():
    population = 0
    if MSA == 0:
        metro_name = "No MSA region"
    else:
        metro_name = regions_df[regions_df['Metro Area']==MSA].Name.iloc[0]
    print(metro_name, MSA_counts[MSA])
# Out:
# No MSA region 2384
# Los Angeles-Long Beach 1523
# Oakland 838
# San Francisco 801
# Salt Lake City-Ogden 760
# Riverside-San Bernardino 515
# San Jose 480
# Sacramento 396
# Pittsburgh 343
# Seattle-Bellevue-Everett 260
# Orange County 234
# Austin-San Marcos 229
# Santa Rosa 216
# Provo-Orem 198
# Portland-Vancouver, OR-WA 188
# Fresno 177
# Washington, DC-MD-VA-WV 173
# Chicago 169
# Vallejo-Fairfield-Napa 158
# Eugene-Springfield 148
# San Luis Obispo-Atascadero-Paso Robles 145
# New York 122
# Boston, MA-NH 120
# Raleigh-Durham-Chapel Hill 115
# Houston 115
# Grand Junction 105
# Santa Barbara-Santa Maria-Lompoc 105
# Minneapolis-St. Paul, MN-WI 101
# San Diego 100
# Indianapolis 96
# Redding 94
# Charlotte-Gastonia-Rock Hill, NC-SC 93
# Denver 91
# Santa Cruz-Watsonville 89
# Baltimore 83
# Yolo 76
# Bakersfield 70
# Phoenix-Mesa 68
# Chico-Paradise 62
# Boise City 60
# Philadelphia, PA-NJ 60
# Tacoma 58
# Albuquerque 56
# Fayetteville-Springdale-Rogers 52
# New Orleans 50
# Medford-Ashland 48
# Detroit 46
# Salinas 46
# Ventura 44
# Madison 41
# Atlanta 40
# Dallas 36
# Las Vegas, NV-AZ 34
# Ann Arbor 34
# Richmond-Petersburg 34
# Yuba City 33
# Newburgh, NY-PA 32
# Reno 32
# Springfield 32
# Boulder-Longmont 32
# Modesto 30
# New Haven-Meriden 30
# Cincinnati, OH-KY-IN 28
# Wilmington 28
# Cleveland-Lorain-Elyria 28
# San Antonio 28
# Des Moines 28
# Providence-Fall River-Warwick, RI-MA 26
# Bremerton 26
# Birmingham 24
# Portland 24
# Stockton-Lodi 24
# Chattanooga, TN-GA 24
# Columbus 24
# Spokane 22
# Salem 22
# Anchorage 21
# Rochester 21
# Colorado Springs 21
# Newark 21
# Baton Rouge 20
# Greensboro--Winston-Salem--High Point 20
# Lubbock 18
# Pittsfield 18
# Milwaukee-Waukesha 18
# Norfolk-Virginia Beach-Newport News, VA-NC 18
# Nassau-Suffolk 18
# Fort Collins-Loveland 18
# Middlesex-Somerset-Hunterdon 18
# Flagstaff, AZ-UT 16
# Visalia-Tulare-Porterville 16
# Charleston-North Charleston 16
# Merced 16
# Asheville 16
# Eau Claire 16
# Hartford 16
# Tampa-St. Petersburg-Clearwater 15
# Orlando 14
# Little Rock-North Little Rock 14
# St. Louis, MO-IL 14
# Santa Fe 14
# Yakima 12
# Tucson 12
# Bergen-Passaic 12
# Buffalo-Niagara Falls 12
# Bellingham 12
# Harrisburg-Lebanon-Carlisle 12
# Tallahassee 12
# Albany-Schenectady-Troy 11
# Sarasota-Bradenton 10
# West Palm Beach-Boca Raton 10
# Gainesville 10
# Bridgeport 10
# Montgomery 10
# Missoula 10
# Kansas City, MO-KS 10
# Fort Worth-Arlington 10
# Houma 10
# Atlantic-Cape May 10
# Allentown-Bethlehem-Easton 10
# Racine 10
# Louisville, KY-IN 9
# Arecibo 9
# Honolulu 8
# El Paso 8
# Fort Lauderdale 8
# Dayton-Springfield 8
# Monmouth-Ocean 8
# Hickory-Morganton-Lenoir 8
# Olympia 8
# Richland-Kennewick-Pasco 8
# Champaign-Urbana 8
# Omaha, NE-IA 6
# New Bedford 6
# Fayetteville 6
# Jacksonville 6
# San Juan-Bayamon 6
# Greenville 6
# Portsmouth-Rochester, NH-ME 6
# Rapid City 6
# State College 6
# Manchester 6
# Brockton 6
# Greenville-Spartanburg-Anderson 6
# Lincoln 6
# Trenton 6
# Fitchburg-Leominster 6
# Danbury 6
# Augusta-Aiken, GA-SC 6
# Wichita 6
# Appleton-Oshkosh-Neenah 5
# Greeley 5
# Corvallis 5
# Akron 4
# Fort Wayne 4
# Pocatello 4
# Dutchess County 4
# Goldsboro 4
# Evansville-Henderson, IN-KY 4
# Dubuque 4
# Binghamton 4
# Columbia 4
# Melbourne-Titusville-Palm Bay 4
# Williamsport 4
# Iowa City 4
# Burlington 4
# Galveston-Texas City 4
# Worcester, MA-CT 4
# Savannah 4
# Scranton--Wilkes-Barre--Hazleton 4
# Tulsa 4
# Utica-Rome 4
# Vineland-Millville-Bridgeton 4
# Waterbury 4
# Nashville 4
# Grand Rapids-Muskegon-Holland 4
# Wilmington-Newark, DE-MD 4
# Mayaguez 4
# Mobile 4
# Lake Charles 4
# Jersey City 4
# Knoxville 4
# Huntsville 4
# Lafayette 4
# Peoria-Pekin 2
# Biloxi-Gulfport-Pascagoula 2
# Beaumont-Port Arthur 2
# Odessa-Midland 2
# Wausau 2
# Oklahoma City 2
# Rochester 2
# Fort Walton Beach 2
# Lansing-East Lansing 2
# Kalamazoo-Battle Creek 2
# Jackson 2
# St. Cloud 2
# Lawrence 2
# Stamford-Norwalk 2
# Sioux Falls 2
# Fort Myers-Cape Coral 2
# Florence 2
# Brazoria 2
# Rockford 2
# Waco 2
# Bloomington-Normal 2
# Punta Gorda 2
# Daytona Beach 2
# Lawton 2
# Janesville-Beloit 2
# Kankakee 2
# Lexington 2
# Lakeland-Winter Haven 2
# Las Cruces 2
# Longview-Marshall 2
# Lowell, MA-NH 2
# Victoria 2
# Hagerstown 2
# Miami 2
# Canton-Massillon 2
# Myrtle Beach 2
# Monroe 2
# Benton Harbor 2
# Erie 2
# Rocky Mount 2
# New London-Norwich, CT-RI 2
# Barnstable-Yarmouth 2
# Joplin 2

# %% [markdown]
# ### Conclusions
#
# LA-Long Beach has the most sensors but over a larger area than the Bay Area. Riverside is an extremely large area, making the number of sensors deceptive. Unfotunately, it's impossible to get geographic area data for these MSAa, but eyeballing it looks like Oakland + San Franciso would be a smaller area than LA but would have more sensors. We could also include San Jose and Santa Rosa for a larger Bay Area look, but that would add a lot of area for not many more sensors. The only other intriguing place is Salt Lake City, which could possibly be combined with Provo-Orem.
